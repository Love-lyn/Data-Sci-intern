# %% [markdown]
# ## import modules

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Housing.csv")

# %%
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB
#               price          area    bedrooms   bathrooms     stories  \
# ...

# %% [markdown]
# ## Drop duplicates

# %%
df.duplicated().sum()
df.drop_duplicates(inplace = True)

# %% [markdown]
# ## Univariate Analysis

# %%
sns.histplot(df['price'], bins = 30)
plt.title('Price Distribution')
plt.ticklabel_format(style= 'plain', axis = 'x')

# %%
sns.histplot(df['area'], kde  =True)
# Out:
# <Axes: xlabel='area', ylabel='Count'>

# %%
df['price'].describe()
# Out:
# count    5.450000e+02
# mean     4.766729e+06
# std      1.870440e+06
# min      1.750000e+06
# 25%      3.430000e+06
# 50%      4.340000e+06
# 75%      5.740000e+06
# max      1.330000e+07
# Name: price, dtype: float64

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.scatterplot(x = 'area', y = 'price', data =df)
plt.title('Area vs Price')
# Out:
# Text(0.5, 1.0, 'Area vs Price')

# %%
sns.boxplot(x = 'bedrooms', y = 'price', data =df)
plt.title('Bedrooms vs Price')
# Out:
# Text(0.5, 1.0, 'Bedrooms vs Price')

# %%
sns.boxplot(x = 'bathrooms', y = 'price', data =df)
plt.title('Bathrooms vs Price')
# Out:
# Text(0.5, 1.0, 'Bathrooms vs Price')

# %%
sns.boxplot(x = 'stories', y = 'price', data =df)
plt.title('Stories vs Price')
# Out:
# Text(0.5, 1.0, 'Stories vs Price')

# %%
sns.boxplot(x = 'furnishingstatus', y = 'price', data =df)
plt.title('Furnsihed rrooms vs Price')
# Out:
# Text(0.5, 1.0, 'Furnsihed rrooms vs Price')

# %% [markdown]
# ## Correlation Analysis

# %%
corr  =df.corr(numeric_only  =True)
sns.heatmap(corr, annot = True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## Dashboard

# %%
fig,axes = plt.subplots(2,2,figsize = (14, 10))
corr  =df.corr(numeric_only  =True)

sns.heatmap(corr, annot = True, ax = axes[0,1])
axes[0,1].set_title('Correlation Matrix')


sns.boxplot(x = 'furnishingstatus', y = 'price', data =df, ax = axes[1,0])
axes[1,0].set_title('Furnsihed vs Price')

sns.scatterplot(x = 'area', y = 'price', data =df, ax = axes[0,0])
axes[0,0].set_title('Area vs Price')

sns.boxplot(x = 'stories', y = 'price', data =df, ax = axes[1,1])
axes[1,1].set_title('Stories vs Price')
# Out:
# Text(0.5, 1.0, 'Stories vs Price')
